# %% [markdown]
# <a href="https://colab.research.google.com/github/seth783/seth-python-practice/blob/main/SETH_PYTHON_PRACTICE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# checking data type

# %%
age=23
name="seth"
print(type(age))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# printing variables

# %%
print("my name is",name,"and my age is",age)
# Out:
# my name is seth and my age is 23

# %%
print(name)
# Out:
# seth

# %%
univ="MASINDE MULIRO UNIVERSITY OF SCIENCE AND TECHNOLOGY"
course="EPIDEMIOLOGY AND BIOSTATISTICS"
knowpy=True

# %%
print(univ)
print(course)
print(knowpy)
print(age)
print(name)
# Out:
# MASINDE MULIRO UNIVERSITY OF SCIENCE AND TECHNOLOGY
# EPIDEMIOLOGY AND BIOSTATISTICS
# True
# 23
# seth

# %% [markdown]
# python operators

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 1000
# 3

# %% [markdown]
# comparison operators

# %%
age =20
print(age==18)
print(age!=18)
print(age>18)
print(age<18)
print(age>=18)
print(age<=18)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# logical operators

# %%
age=30
student=True
print(age>20 and student)
print(age>20 or student)
print(not student)
# Out:
# True
# True
# False

# %% [markdown]
# practice

# %%
x=15
y=4
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
print(x>y)
print(x>10 and y>5)
print(x<10 or y!=4)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3
# True
# False
# False

# %%
price =1500
quantity =4
tc=price*quantity
print(price*quantity)
print(tc>5000)
print(tc==6000)
# Out:
# 6000
# True
# True

# %% [markdown]
# creating a list

# %%
fruits=["apple","banana","orange","mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %% [markdown]
# acessing list items

# %%
fruits=["apple","banana","orange","mango"]
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
print(fruits[-1])
print(fruits[-2])
print(fruits[-3])
print(fruits[-4])
# Out:
# apple
# banana
# orange
# mango
# mango
# orange
# banana
# apple

# %% [markdown]
# changing an item

# %%
fruits=["apple","banana","orange","mango"]
fruits[0]="kiwi"
print(fruits)
# Out:
# ['kiwi', 'banana', 'orange', 'mango']

# %% [markdown]
# adding items

# %%
fruits=["apple","banana","orange","mango"]
fruits.append("kiwi")
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango', 'kiwi']

# %% [markdown]
# removing items

# %%
fruits=["apple","banana","orange","mango"]
fruits.remove("apple")
print(fruits)
# Out:
# ['banana', 'orange', 'mango']

# %% [markdown]
# finding the lenght of a list

# %%
fruits=["apple","banana","orange","mango"]
print(len(fruits))
# Out:
# 4

# %% [markdown]
# looping through a list

# %%
fruits=["apple","banana","orange","mango"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange
# mango

# %% [markdown]
# practice

# %%
subjects=["mats","english","biology","chemistry"]
print(subjects)
print(subjects[0])
print(subjects[3])
# Out:
# ['mats', 'english', 'biology', 'chemistry']
# mats
# chemistry

# %%
subjects.append("physics")
print(subjects)
# Out:
# ['mats', 'english', 'biology', 'chemistry', 'physics']

# %% [markdown]
# removing an item from the list

# %%
subjects.remove("biology")
print(subjects)
# Out:
# ['mats', 'english', 'chemistry', 'physics']

# %%
for subject in subjects:
    print(subject)
# Out:
# mats
# biology
# chemistry
# physics

# %%
hp=(2000,1500,60000,39000,37000)
print(hp)
# Out:
# (2000, 1500, 60000, 39000, 37000)

# %%
max(hp)
# Out:
# 60000

# %%
min(hp)
# Out:
# 1500

# %%
sum(hp)
# Out:
# 139500

# %%
len(hp)
# Out:
# 5

# %%
sum(hp)/len(hp)
# Out:
# 27900.0

# %% [markdown]
# dictionaries

# %%
student={
    "name": "seth",
    "age": 21,
    "course": "epidemiology and biostatistics",
    "university": "MASINDE MULIRO UNIVERSITY OF SCIENCE AND TECHNOLOGY"
}
print(student)
# Out:
# {'name': 'seth', 'age': 21, 'course': 'epidemiology and biostatistics', 'university': 'MASINDE MULIRO UNIVERSITY OF SCIENCE AND TECHNOLOGY'}

# %%
print(student["age"],student["name"])
# Out:
# 21 seth

# %%
student["nationality"]="kenya"
print(student)
# Out:
# {'name': 'seth', 'age': 21, 'course': 'epidemiology and biostatistics', 'university': 'MASINDE MULIRO UNIVERSITY OF SCIENCE AND TECHNOLOGY', 'nationality': 'kenya'}

# %%
student["university"]="mmust"
student["age"]=20
print(student)
# Out:
# {'name': 'seth', 'age': 20, 'course': 'epidemiology and biostatistics', 'university': 'mmust', 'nationality': 'kenya'}

# %%
student.pop("nationality")
print(student)
# Out:
# {'name': 'seth', 'age': 20, 'course': 'epidemiology and biostatistics', 'university': 'mmust'}

# %%
for key , value in student.items():
  print(key,"-",value)
# Out:
# name - seth
# age - 20
# course - epidemiology and biostatistics
# university - mmust

# %%
days=("monday","tuesday","wednesday","thursday","friday","saturday","sunday")
print(days)
# Out:
# ('monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday')

# %%
print(days[0])
print(days[6])
# Out:
# monday
# sunday

# %%
book={
    "tittle":"unplugged alpha",
    "author":"james bond",
    "pages":400,
    "price":3000}
print(book)
# Out:
# {'tittle': 'unplugged alpha', 'author': 'james bond', 'pages': 400, 'price': 3000}

# %%
print(book["tittle"],book["price"])
# Out:
# unplugged alpha 3000

# %%
book["price"]=4000
print(book['price'])
# Out:
# 4000

# %%
book["publisher"]="longhoren publishers"
print(book)
# Out:
# {'tittle': 'unplugged alpha', 'author': 'james bond', 'pages': 400, 'price': 4000, 'publisher': 'longhoren publishers'}

# %%
for key,value in book.items():
  print(key,"-",value)
# Out:
# tittle - unplugged alpha
# author - james bond
# pages - 400
# price - 4000
# publisher - longhoren publishers

# %%
num=18
if num % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# even

# %%
print(num % 2)
# Out:
# 0

# %%
marks=75
if marks >=70:
  print("pass")
else:
  print("fail")
# Out:
# pass

# %%
age=13
if age < 13:
  print("child")
elif age >=13 and age <=19:
 print("teenager")
else:
  print("adult")
# Out:
# teenager

# %%
balance=10009
if balance > 10000:
  print("premium account")
elif balance >=5000 and balance <= 9999:
  print("standard account")
else:
  print("basic account")
# Out:
# premium account
